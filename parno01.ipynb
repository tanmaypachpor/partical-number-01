# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dataset = pd.read_csv(r"C:\Users\91842\Downloads\tseries_top_videos.csv")

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
df.isnull().sum()
# Out:
# channel          0
# title            0
# published_at     0
# duration         0
# view_count       0
# like_count       0
# comment_count    0
# dtype: int64

# %%
print(df.notnull().sum())
# Out:
# channel          29
# title            29
# published_at     29
# duration         29
# view_count       29
# like_count       29
# comment_count    29
# dtype: int64

# %%
df_cleaned=df.dropna()
print(df_cleaned)
print(df_cleaned.notnull().sum())
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
df_filled=df.fillna(0)
print(df_filled)
print(df_filled.notnull().sum())
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
df.replaceed=df.replace('12988151','0')
print(df.replaceed)
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
df_interpolated=df.interpolate()
print(df_interpolated)
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
nan_mask=df.isnull()
nan_values=df[nan_mask]
print(df)
print(nan_values)
# Out:
#      channel                                              title  \
# 0   T-Series  Vaaste Song: Dhvani Bhanushali, Tanishk Bagchi...
# 1   T-Series  Lut Gaye (Full Song) Emraan Hashmi, Yukti | Ju...
# 2   T-Series  DILBAR Lyrical | Satyameva Jayate |John Abraha...
# 3   T-Series  SIMMBA: Aankh Marey Lyrical | Ranveer Singh, S...
# 4   T-Series  Guru Randhawa: High Rated Gabru Official Song ...
# 5   T-Series  Cham Cham Full Video | BAAGHI | Tiger Shroff, ...
# 6   T-Series  Guru Randhawa: Lahore (Official Video) Bhushan...
# 7   T-Series  Bom Diggy Diggy  (VIDEO) | Zack Knight | Jasmi...
# 8   T-Series  Bum Bum Bole (Full Song) Film - Taare Zameen P...
# 9   T-Series  Full Song: KHAIRIYAT (BONUS TRACK) | CHHICHHOR...
# 10  T-Series  Leja Re | Dhvani Bhanushali | Tanishk Bagchi |...
# 11  T-Series  SIMMBA: Aankh Marey | Ranveer Singh, Sara Ali ...
# 12  T-Series  Official Video: Humnava Mere Song | Jubin Naut...
# 13  T-Series  'PREM RATAN DHAN PAYO' Title Song (Full VIDEO)...
# ...

# %%
age_condition=df['comment_count']>1000000
filtered_data=df[age_condition]
print(filtered_data)
# Out:
# Empty DataFrame
# Columns: [channel, title, published_at, duration, view_count, like_count, comment_count]
# Index: []
